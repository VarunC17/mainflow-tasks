# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter
from matplotlib import colors
from mpl_toolkits.mplot3d import Axes3D
import datetime
import random
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Varun Contractor\\Documents\\tasks\\disney_plus_titles.csv')
df.shape
# Out:
# (1368, 12)

# %%
df.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info
# Out:
# <bound method DataFrame.info of      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# ...

# %%
description = df.describe()
print(description)
# Out:
#        release_year
# count   1368.000000
# mean    2002.348684
# std       22.127559
# min     1928.000000
# 25%     1998.000000
# 50%     2011.000000
# 75%     2018.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# release_year      0
# rating            2
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
df2 = df.fillna(value=0)
df2
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                              0
# 4                              0
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# ...

# %%
from scipy import stats

# %%
df2.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head(21)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                                      A Spark Story
# 1       s2    Movie                                     Spooky Buddies
# 2       s3    Movie                             The Fault in Our Stars
# 3       s4  TV Show                                    Dog: Impossible
# 4       s5  TV Show                     Spidey And His Amazing Friends
# 5       s6  TV Show                                 Star Wars: Visions
# 6       s7    Movie                        Confessions of a Shopaholic
# 7       s8    Movie                         Descendants: Royal Wedding
# 8       s9    Movie  Disney's Broadway Hits at London's Royal Alber...
# 9      s10    Movie                          Flooded Tombs of the Nile
# 10     s11    Movie                                  Jade Eyed Leopard
# 11     s12    Movie                                               Nona
# ...

# %%
plt.scatter(df['type'],df['release_year'],color='coral')
plt.title('Scatter Plot')
plt.xlabel('Type')
plt.ylabel('Year of release')
plt.show()

# %%
plt.bar(df['release_year'],df['duration'],color='lightskyblue')
plt.title('Bar Chart')
plt.xlabel('')
plt.ylabel('')
plt.xlim(2012,2021)
plt.ylim(120,150)
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=df, x='date_added', y='release_year', color='khaki')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.title('Date v/s Release year')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
df['date_added']= pd.to_datetime(df['date_added'])
df.set_index('date_added',inplace=True)

# %%
monthly_data=df['show_id'].resample('ME').count()

# %%
decomposition=seasonal_decompose(monthly_data, model='additive')
decomposition.plot()
plt.show()
